# %%
# this code picks a column from excel sheet and returns a CSV on selection
import pandas as pd
df=pd.read_excel(r"C:\Users\jyoth\TheSentimentalistsPythonCode\News papers.xlsx", sheet_name=0, usecols=['Website','Article','Credibility score','Whole Article polarity (-1 to +1)','Whole Article subjectivity (0 to 1)'])
#df.to_csv('WebsiteArticleDataForBiasCalcIMP.csv')
print(df)
# Out:
#                                               Website  \
# 0                                                 NaN
# 1                            https://www.foxnews.com/
# 2                          https://www.breitbart.com/
# 3                              https://www.msnbc.com/
# 4                      https://www.huffingtonpost.com
# 5                                    https://cnn.com/
# 6                        https://www.motherjones.com/
# 7                                https://www.vox.com/
# 8                            https://www.nytimes.com/
# 9                            https://www.nbcnews.com/
# 10                    https://www.washingtonpost.com/
# 11                            https://abcnews.go.com/
# 12                           https://www.cbsnews.com/
# 13                           https://eu.usatoday.com/
# 14                               https://www.wsj.com/
# 15                  https://www.npr.org/sections/news
# ...
